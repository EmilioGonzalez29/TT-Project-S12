# %% [markdown]
# # Visualización del dataset y análisis de errores

# %% [markdown]
# ## Importación del dataset y visualización

# %%
import pandas as pd

# %%
df = pd.read_csv('./dataset/trending_by_time.csv')
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12343 entries, 0 to 12342
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   record_id       12343 non-null  int64
#  1   region          12343 non-null  object
#  2   trending_date   12343 non-null  object
#  3   category_title  12343 non-null  object
#  4   videos_count    12343 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 482.3+ KB
# None
#    record_id  region               trending_date    category_title  \
# 0          1  France  2017-11-14 00:00:00.000000  Autos & Vehicles
# 1          2  France  2017-11-15 00:00:00.000000  Autos & Vehicles
# 2          3  France  2017-11-16 00:00:00.000000  Autos & Vehicles
# 3          4  France  2017-11-17 00:00:00.000000  Autos & Vehicles
# 4          5  France  2017-11-18 00:00:00.000000  Autos & Vehicles
#
#    videos_count
# 0             8
# 1             2
# 2             6
# ...

# %% [markdown]
# ## Detección de errores en los datos

# %%
def error_detection(df): #Función para detectar errores en dataset y convertir todos los títulos de columnas en convención snake_case
    #Detección de valores ausentes por columna:
    for column in df:
        print(f'Valores ausentes en columna {column}:', df[column].isna().sum())
    print()
    #Detección de filas duplicadas:
    print('Cantidad de filas duplicadas:', df.duplicated().sum())
    print()
    #Cambiar formato erróneo en nombres de columnas:
    new_col_name = {}
    for column in df:
        new_col_name[column]= column.strip().lower().replace(' ', '_')
    df.rename(columns=new_col_name, inplace=True)
    return df

# %%
error_detection(df)
# Out:
# Valores ausentes en columna record_id: 0
# Valores ausentes en columna region: 0
# Valores ausentes en columna trending_date: 0
# Valores ausentes en columna category_title: 0
# Valores ausentes en columna videos_count: 0
#
# Cantidad de filas duplicadas: 0
#        record_id         region               trending_date    category_title  \
# 0              1         France  2017-11-14 00:00:00.000000  Autos & Vehicles
# 1              2         France  2017-11-15 00:00:00.000000  Autos & Vehicles
# 2              3         France  2017-11-16 00:00:00.000000  Autos & Vehicles
# 3              4         France  2017-11-17 00:00:00.000000  Autos & Vehicles
# 4              5         France  2017-11-18 00:00:00.000000  Autos & Vehicles
# ...          ...            ...                         ...               ...
# 12338      12339  United States  2018-06-10 00:00:00.000000   Travel & Events
# 12339      12340  United States  2018-06-11 00:00:00.000000   Travel & Events
# ...

# %% [markdown]
# Conclusión:
# El dataset no contiene valores ausentes, ni filas duplicadas. Está en condiciones de utilizarse para la creación del dashboard.
